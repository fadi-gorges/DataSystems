# %%
import boto3

# Let's use Amazon S3
s3 = boto3.resource('s3')

# %%
import pandas as pd

# %% [markdown]
# ### Importing Dataset from AWS S3 for executing more complex data transformations:

# %%
# Print out bucket names
for bucket in s3.buckets.all():
    print(bucket.name)
# Out:
# 41091-vehicle-data-system-data-storage
# aws-glue-assets-381491871117-ap-southeast-2

# %%
s3 = boto3.client('s3')

# %% [markdown]
# ##### Below is code to download the data file from S3 after the glue transformations

# %%
#s3.download_file(Bucket ='41091-vehicle-data-system-data-storage',Key='transformed_data/vehicle_data_cleaned/vehicle_data_parquet/dataload=20240513/run-1715586526929-part-block-0-r-00000-snappy.parquet' ,Filename = 'run-1715586526929-part-block-0-r-00000-snappy.parquet')

# %% [markdown]
# ##### After downloading the parquet file from S3, the parquet file is read using pandas.

# %%
cleaned_data = pd.read_parquet('/Users/haroondeen/Desktop/Data Systems/Car Data ETL/run-1715586526929-part-block-0-r-00000-snappy.parquet')

# %%
cleaned_data.head()
# Out:
#    vehicleid   brand  year  model  \
# 0          0  Abarth  2021    595
# 1          1  Abarth  2021    595
# 2          4    Alfa  2015  Romeo
# 3          5    Alfa  2008  Romeo
# 4          7    Alfa  2014  Romeo
#
#                                           title usedornew transmission  \
# 0                  2021 Abarth 595 Competizione      USED       Manual
# 1                  2021 Abarth 595 Competizione      USED    Automatic
# 2  2015 Alfa Romeo Giulietta Quadrifoglio Verde      USED    Automatic
# 3                   2008 Alfa Romeo 159 2.2 JTS      USED    Automatic
# 4              2014 Alfa Romeo Mito Progression      USED       Manual
#
#    engine drivetype fueltype  ... cylindersinengine   bodytype doors seats  \
# 0     1.4     Front  Premium  ...               4.0  Hatchback     3     4
# 1     1.4     Front  Premium  ...               4.0  Hatchback     3     4
# 2     1.7     Front  Premium  ...               4.0  Hatchback     5     5
# 3     2.2     Front  Premium  ...               4.0      Sedan     4     5
# 4     1.4     Front  Premium  ...               4.0  Hatchback     3     5
#
#    price                   Unique_Vehicle_Id#0       Suburb State  \
# 0  36990  e14283be-4755-42fa-ab75-2f9cea04a2b0         Ryde   NSW
# 1  37990  64d1c21f-5a89-46bf-9d11-db1d6b5addbc     Pakenham   VIC
# 2  24995  5e7f2196-f84b-4b27-81c6-81c3981b2269  Minchinbury   NSW
# 3  12890  7e026bd0-1e1a-4a7a-8d96-6f4af8980647     Ringwood   VIC
# 4  10692  cd237ac7-4cdb-46b6-b790-49642fa7be0e       Hendra   QLD
#
#   Exterior_Colour Interior_Colour
# 0          Black            Black
# 1           Grey            Black
# 2          White    Black Leather
# 3           Grey            Black
# 4          White            Black
#
# [5 rows x 22 columns]

# %%
cleaned_data.dtypes
# Out:
# vehicleid                int64
# brand                   object
# year                     int32
# model                   object
# title                   object
# usedornew               object
# transmission            object
# engine                 float32
# drivetype               object
# fueltype                object
# fuelconsumption         object
# kilometres               int32
# cylindersinengine       object
# bodytype                object
# doors                    int32
# seats                    int32
# price                    int32
# Unique_Vehicle_Id#0     object
# Suburb                  object
# State                   object
# Exterior_Colour         object
# Interior_Colour         object
# dtype: object

# %% [markdown]
# ##### After reading the file in pandas, the data transformations for the parquet file are done using pandas methods.

# %%
cleaned_data = cleaned_data.rename(columns= {'Unique_Vehicle_Id#0':'Unique_Vehicle_ID'})

# %%
words_to_remove = 3

# %%
cleaned_data['title'] = cleaned_data['title'].str.split(' ', n=words_to_remove).str[words_to_remove]

# %%
cleaned_data
# Out:
#       vehicleid   brand  year  model                         title usedornew  \
# 0             0  Abarth  2021    595                  Competizione      USED
# 1             1  Abarth  2021    595                  Competizione      USED
# 2             4    Alfa  2015  Romeo  Giulietta Quadrifoglio Verde      USED
# 3             5    Alfa  2008  Romeo                   159 2.2 JTS      USED
# 4             7    Alfa  2014  Romeo              Mito Progression      USED
# ...         ...     ...   ...    ...                           ...       ...
# 7324      16722   Volvo  2022   XC40          T4 Inscription (awd)      USED
# 7325      16723   Volvo  2019   XC60                   D4 Momentum      USED
# 7326      16724   Volvo  2014    S60                    T4 Kinetic      USED
# 7327      16727   Volvo  2022   XC60                  Plus B5 Mhev      DEMO
# 7328      16730   Volvo  2017   XC60                   D5 R-Design      USED
#
#      transmission  engine drivetype fueltype  ... cylindersinengine  \
# 0          Manual     1.4     Front  Premium  ...               4.0
# 1       Automatic     1.4     Front  Premium  ...               4.0
# 2       Automatic     1.7     Front  Premium  ...               4.0
# 3       Automatic     2.2     Front  Premium  ...               4.0
# 4          Manual     1.4     Front  Premium  ...               4.0
# ...           ...     ...       ...      ...  ...               ...
# 7324    Automatic     2.0       AWD  Premium  ...               4.0
# 7325    Automatic     2.0       AWD   Diesel  ...               4.0
# 7326    Automatic     1.6     Front  Premium  ...               4.0
# 7327    Automatic     2.0       AWD  Premium  ...               4.0
# 7328    Automatic     2.0       AWD   Diesel  ...               4.0
#
#        bodytype doors seats  price                     Unique_Vehicle_ID  \
# 0     Hatchback     3     4  36990  e14283be-4755-42fa-ab75-2f9cea04a2b0
# 1     Hatchback     3     4  37990  64d1c21f-5a89-46bf-9d11-db1d6b5addbc
# 2     Hatchback     5     5  24995  5e7f2196-f84b-4b27-81c6-81c3981b2269
# 3         Sedan     4     5  12890  7e026bd0-1e1a-4a7a-8d96-6f4af8980647
# 4     Hatchback     3     5  10692  cd237ac7-4cdb-46b6-b790-49642fa7be0e
# ...         ...   ...   ...    ...                                   ...
# 7324        SUV     4     5  55990  00b7772d-99b4-43d4-9ad2-54edf9016620
# 7325        SUV     4     5  47888  341400da-6b08-4c06-b872-8eb1be668896
# 7326      Sedan     4     5  13990  3fd804c2-1c0b-4994-856b-74de6a50cefe
# 7327        SUV     4     5  69990  ddc976d3-1996-488c-8ba2-d8c9f4381303
# 7328        SUV     4     5  51888  082f0430-3ab1-44b8-abcc-57279b177fa7
#
#             Suburb State Exterior_Colour    Interior_Colour
# 0             Ryde   NSW          Black               Black
# 1         Pakenham   VIC           Grey               Black
# 2      Minchinbury   NSW          White       Black Leather
# 3         Ringwood   VIC           Grey               Black
# 4           Hendra   QLD          White               Black
# ...            ...   ...             ...                ...
# 7324    Launceston   TAS           Blue               Black
# 7325       Wickham   NSW          White               Black
# 7326    Cabramatta   NSW          White               Black
# 7327  Warwick Farm   NSW           Blue    Charcoal Leather
# 7328       Totness    SA           Blue               Black
#
# [7329 rows x 22 columns]

# %%
cleaned_data_pt2= cleaned_data[[ 'vehicleid','Unique_Vehicle_ID' ,'brand', 'year', 'model', 'title', 'usedornew', 'transmission', 'engine', 'drivetype', 'fueltype', 'fuelconsumption' , 'kilometres', 'cylindersinengine', 'bodytype', 'Suburb', 'State' ,'doors', 'seats','Exterior_Colour', 'Interior_Colour', 'price']]

# %%
cleaned_data_pt2.head()
# Out:
#    vehicleid                     Unique_Vehicle_ID   brand  year  model  \
# 0          0  e14283be-4755-42fa-ab75-2f9cea04a2b0  Abarth  2021    595
# 1          1  64d1c21f-5a89-46bf-9d11-db1d6b5addbc  Abarth  2021    595
# 2          4  5e7f2196-f84b-4b27-81c6-81c3981b2269    Alfa  2015  Romeo
# 3          5  7e026bd0-1e1a-4a7a-8d96-6f4af8980647    Alfa  2008  Romeo
# 4          7  cd237ac7-4cdb-46b6-b790-49642fa7be0e    Alfa  2014  Romeo
#
#                           title usedornew transmission  engine drivetype  ...  \
# 0                  Competizione      USED       Manual     1.4     Front  ...
# 1                  Competizione      USED    Automatic     1.4     Front  ...
# 2  Giulietta Quadrifoglio Verde      USED    Automatic     1.7     Front  ...
# 3                   159 2.2 JTS      USED    Automatic     2.2     Front  ...
# 4              Mito Progression      USED       Manual     1.4     Front  ...
#
#   kilometres cylindersinengine   bodytype       Suburb State doors seats  \
# 0      13200               4.0  Hatchback         Ryde   NSW     3     4
# 1      14901               4.0  Hatchback     Pakenham   VIC     3     4
# 2      98446               4.0  Hatchback  Minchinbury   NSW     5     5
# 3     104776               4.0      Sedan     Ringwood   VIC     4     5
# 4      92500               4.0  Hatchback       Hendra   QLD     3     5
#
#    Exterior_Colour  Interior_Colour  price
# 0           Black             Black  36990
# 1            Grey             Black  37990
# 2           White     Black Leather  24995
# 3            Grey             Black  12890
# 4           White             Black  10692
#
# [5 rows x 22 columns]

# %% [markdown]
# ##### After the data transformations are complete, the dataframe is converted into a csv file which is then loaded into AWS S3 Bucket

# %%
cleaned_data_pt2.to_csv('Clean_data_stage_1_csv/final_data_fixed.csv', index= False)

# %%
#s3.upload_file(Filename='Clean_data_stage_1_csv/final_data_fixed.csv', Bucket ='41091-vehicle-data-system-data-storage',Key='transformed_data/vehicle_data_cleaned/cleaned_data_csv/dataload=20240513/final_data.csv')
